# %% [markdown]
# # Missionários em segurança com canibais
# O intuito desse trabalho é gerenciar o uso do barco para que todos os missionários da paróquia do Frei Sardinha consiga atravessar o rio em segurança na companhia dos queridos indígenas Caetés. Mas para garantir a segurança de todos, principalmente dos missionários, existem algumas regras que devem ser respeitadas.
#
# Primeiramente, o problema considera duas margens do rio: a margem inicial (esquerda) e a margem de destino (direita). Todos os indivíduos começam na margem inicial e devem ser transportados para a margem de destino.
#
# O transporte é realizado por meio de um barco, que possui capacidade limitada, podendo transportar no máximo um número fixo de pessoas por travessia.

# %% [markdown]
# ## Regras
#
# As regras que regem o problema são as seguintes:
#
# - O barco deve sempre transportar pelo menos uma pessoa, o barco nunca se desloca sozinho.
# - Em nenhuma das margens do rio pode haver um número de indígenas maior que o de missionários, caso exista pelo menos um missionário presente naquela margem. Caso contrário, os missionários seriam colocados em risco.

# %% [markdown]
# ## Definições iniciais

# %%
from time import perf_counter
from collections import deque

# possibilita que os parâmetros possam ser redefinidos conforme necessidade do cenário
def set_initial_state(missionaries=3, cannibals=3, boat="left"):
    state = {
        "left": (missionaries, cannibals),
        "right": (0, 0),
        "boat": boat
    }
    return state
initial_state = set_initial_state()

#melhora a qualidade de exibição das métricas e estatísticas
def print_metrics(metrics):
    print("\n📊 MÉTRICAS DE EXECUÇÃO")
    print("=" * 35)

    print(f"Sucesso: {'✅' if metrics['sucesso'] else '❌'}")

    print(f"Tempo de execução: {metrics['tempo_de_execução']:.6f} s")

    print(f"Estados verificados: {metrics['estados_verificados']:,}".replace(",", "."))
    print(f"Nós gerados: {metrics['nodes_gerados']:,}".replace(",", "."))
    print(f"Nós expandidos: {metrics['nodes_expandidos']:,}".replace(",", "."))

    print(f"Tamanho máximo da fila: {metrics['tamanho_maximo_pilha']:,}".replace(",", "."))

    profundidade = metrics["profundidade_solucao"]
    if profundidade is not None:
        print(f"Profundidade da solução: {profundidade}")
    else:
        print("Profundidade da solução: —")

    print("=" * 35)

# %% [markdown]
# ### Validação
# A validação consiste em verificar em cada margem, se há mais canibais que missionarios.

# %%
def is_valid(state):
    left_missionaries, left_cannibals = state["left"]
    right_missionaries, right_cannibals = state["right"]

    if min(left_missionaries, left_cannibals, right_missionaries, right_cannibals) < 0:
        return False

    if left_missionaries > 0 and left_cannibals > left_missionaries:
        return False

    if right_missionaries > 0 and right_cannibals > right_missionaries:
        return False

    return True

# %% [markdown]
# ### Função sucessor
# É listado todos os movimentos possíveis de acordo com a quantidade de lugares no barco, por meio da soma do valor dos index, é possível comparar quantas pessoas de cada cultura cabe no espaço do barco.

# %%
def possible_moves(boat_capacity):
    moves = []
    
    for m in range(boat_capacity + 1):
        for c in range(boat_capacity + 1):
            total = m + c
            
            if 1 <= total <= boat_capacity:
                moves.append((m, c))
    
    return moves

# %%
possible_moves(2) # Um exemplo de uso com o máximo de duas pessoas no barco
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (2, 0), (2, 1), (3, 0)]

# %% [markdown]
# Com isso, podemos finalmente criar a função que aplica os movimentos:

# %%
def apply_move(state, move):
    missionaries, cannibals = move
    left_missionaries, left_cannibals = state["left"]
    right_missionaries, right_cannibals = state["right"]

    if state["boat"] == "left":
        return {
            "left": (left_missionaries - missionaries, left_cannibals - cannibals),
            "right": (right_missionaries + missionaries, right_cannibals + cannibals),
            "boat": "right"
        }
    else:
        return {
            "left": (left_missionaries + missionaries, left_cannibals + cannibals),
            "right": (right_missionaries - missionaries, right_cannibals - cannibals),
            "boat": "left"
        }

# %%
# Test
initial_state = set_initial_state(3, 3)
new_state = apply_move(initial_state, (2, 1))
print(new_state)
print("Válido?", is_valid(new_state))
# Out:
# {'left': (1, 2), 'right': (2, 1), 'boat': 'right'}
# Válido? False

# %% [markdown]
# ### Explicação da função sucessor
# A função sucessor é responsável por gerar, a partir de um estado atual, todos os próximos estados possíveis que podem ser alcançados em **uma única travessia** do barco. Para isso, ela combina três etapas já definidas anteriormente:
#
# 1. Obtém todos os movimentos possíveis por meio da função `possible_moves()` (combinações de missionários e canibais que cabem no barco).
# 2. Aplica cada movimento ao estado atual com a função `apply_move(state, move)`, produzindo um novo estado candidato.
# 3. Valida esse novo estado com `is_valid(new_state)`, descartando automaticamente estados que violam as regras do problema.
#
# Ao final, a função retorna uma lista de pares `(movimento, novo_estado)`. Essa estrutura é essencial para os algoritmos de busca (como o BFS), pois permite explorar o espaço de estados de forma sistemática, mantendo apenas transições válidas e seguras.

# %%
def successors(state, boat_capacity):
    result = []

    for move in possible_moves(boat_capacity):
        new_state = apply_move(state, move)

        if is_valid(new_state):
            result.append((move, new_state))

    return result

# %%
def is_goal(state):
    return state["left"] == (0, 0)

# %% [markdown]
# ## BFS - Busca em Largura

# %%
# Recebe um estado inicial e a capacidade do barco, que podem
def solve_bfs(initial_state, boat_capacity = 2):
    start_time = perf_counter()
    queue = deque([{
        "state": initial_state,
        "path": [],
        "movements": [(0,0)]
    }])

    visited = {
        (
            initial_state["left"],
            initial_state["right"],
            initial_state["boat"]
        )
    }

    generated_nodes = 1
    expanded_nodes = 0
    max_queue_size = 1

    while queue:
        max_queue_size = max(max_queue_size, len(queue))
        
        node = queue.popleft()
        expanded_nodes += 1

        state = node["state"]
        path = node["path"]
        movements = node["movements"]

        if is_goal(state):
            end_time = perf_counter()
            solution = path + [state]

            success_metrics = {
                "sucesso": True,
                "tempo_de_execução": end_time - start_time,
                "estados_verificados": len(visited),
                "nodes_gerados": generated_nodes,
                "nodes_expandidos": expanded_nodes,
                "tamanho_maximo_pilha": max_queue_size,
                "profundidade_solucao": len(solution) - 1
            }
            
            return solution, movements, success_metrics

        #obtem uma lista de movimentos e estados que esses movimentos geram
        for move, new_state in successors(state, boat_capacity):
            state_key = (
                new_state["left"],
                new_state["right"],
                new_state["boat"]
            )

            # verifica se o estado analisado é um estado que nunca foi visitado, 
            # se não for, esse estado é adicionado na fila pra processamento futuro
            if state_key not in visited:
                visited.add(state_key)
                generated_nodes += 1

                queue.append({
                    "state": new_state,
                    "path": path + [state],
                    "movements": movements + [move]
                })
                
    end_time = perf_counter()

    failed_metrics = {
        "sucesso": False,
        "tempo_de_execução": end_time - start_time,
        "estados_verificados": len(visited),
        "nodes_gerados": generated_nodes,
        "nodes_expandidos": expanded_nodes,
        "tamanho_maximo_pilha": max_queue_size,
        "profundidade_solucao": None
    }


    return None, None, failed_metrics

# %%
initial_state = set_initial_state(420,4)
solution, movements, metrics = solve_bfs(initial_state, 8)

if solution and movements:
    
    total_steps = len(movements) - 1  # ignorando (0,0)

    if total_steps > 20:
        print("Solução muito longa, não será exibida.")
    else:
        print("\nGabarito da travessia:")
        boat_side = "left"
    
        for step, move in enumerate(movements[1:], start=1):
            missionaries, cannibals = move
            origin = "esquerda" if boat_side == "left" else "direita"
            destination = "direita" if boat_side == "left" else "esquerda"
    
            missionaries_label = "missionário" if missionaries == 1 else "missionários"
            cannibals_label = "canibal" if cannibals == 1 else "canibais"
    
            print(
                f"Passo {step}: levar {missionaries} {missionaries_label} e "
                f"{cannibals} {cannibals_label} da margem {origin} para a margem {destination}."
            )
    
            boat_side = "right" if boat_side == "left" else "left"
else:
    print("Nenhuma solução encontrada")

print_metrics(metrics)
# Out:
# Solução muito longa, não será exibida.
#
# 📊 MÉTRICAS DE EXECUÇÃO
# ===================================
# Sucesso: ✅
# Tempo de execução: 0.101201 s
# Estados verificados: 4.182
# Nós gerados: 4.182
# Nós expandidos: 4.176
# Tamanho máximo da fila: 38
# Profundidade da solução: 121
# ===================================

# %% [markdown]
# ## DFS - Busca em Profundidade
# A busca em profundidade explora um caminho até o fim antes de voltar (backtracking) para tentar alternativas. Aqui, usamos uma pilha para controlar os estados pendentes e também evitamos revisitar estados já explorados.

# %%
def solve_dfs(initial_state, boat_capacity=2):
    stack = [{
        "state": initial_state,
        "path": [],
        "movements": [(0, 0)]
    }]

    visited = {
        (
            initial_state["left"],
            initial_state["right"],
            initial_state["boat"]
        )
    }

    while stack:
        node = stack.pop()

        state = node["state"]
        path = node["path"]
        movements = node["movements"]

        if is_goal(state):
            return path + [state], movements

        for move, new_state in successors(state, boat_capacity):
            state_key = (
                new_state["left"],
                new_state["right"],
                new_state["boat"]
            )

            if state_key not in visited:
                visited.add(state_key)
                stack.append({
                    "state": new_state,
                    "path": path + [state],
                    "movements": movements + [move]
                })

    return None, None

# %%
solution_dfs, movements_dfs = solve_dfs(initial_state, 3)

if solution_dfs and movements_dfs:
    print("\nGabarito da travessia (DFS):")
    boat_side = "left"

    for step, move in enumerate(movements_dfs[1:], start=1):
        missionaries, cannibals = move
        origin = "esquerda" if boat_side == "left" else "direita"
        destination = "direita" if boat_side == "left" else "esquerda"

        missionaries_label = "missionário" if missionaries == 1 else "missionários"
        cannibals_label = "canibal" if cannibals == 1 else "canibais"

        print(
            f"Passo {step}: levar {missionaries} {missionaries_label} e "
            f"{cannibals} {cannibals_label} da margem {origin} para a margem {destination}."
        )

        boat_side = "right" if boat_side == "left" else "left"
else:
    print("Nenhuma solução encontrada com DFS")
# Out:
# Estados da solução em DFS (passo a passo):
# Passo 0
# {'left': (420, 4), 'right': (0, 0), 'boat': 'left'} através de (0, 0)
# ------------------------------
# Passo 1
# {'left': (417, 4), 'right': (3, 0), 'boat': 'right'} através de (3, 0)
# ------------------------------
# Passo 2
# {'left': (419, 4), 'right': (1, 0), 'boat': 'left'} através de (2, 0)
# ------------------------------
# Passo 3
# {'left': (416, 4), 'right': (4, 0), 'boat': 'right'} através de (3, 0)
# ------------------------------
# Passo 4
# {'left': (417, 4), 'right': (3, 0), 'boat': 'left'} através de (1, 0)
# ------------------------------
# Passo 5
# {'left': (414, 4), 'right': (6, 0), 'boat': 'right'} através de (3, 0)
# ------------------------------
# Passo
levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 411: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 412: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 413: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 414: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 415: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 416: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 417: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 418: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 419: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 420: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 421: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 422: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 423: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 424: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 425: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 426: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 427: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 428: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 429: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 430: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 431: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 432: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 433: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 434: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 435: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 436: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 437: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 438: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 439: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 440: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 441: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 442: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 443: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 444: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 445: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 446: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 447: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 448: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 449: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 450: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 451: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 452: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 453: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 454: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 455: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 456: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 457: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 458: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 459: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 460: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 461: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 462: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 463: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 464: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 465: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 466: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 467: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 468: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 469: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 470: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 471: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 472: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 473: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 474: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 475: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 476: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 477: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 478: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 479: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 480: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 481: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 482: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 483: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 484: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 485: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 486: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 487: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 488: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 489: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 490: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 491: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 492: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 493: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 494: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 495: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 496: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 497: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 498: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 499: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 500: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 501: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 502: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 503: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 504: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 505: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 506: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 507: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 508: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 509: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 510: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 511: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 512: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 513: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 514: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 515: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 516: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 517: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 518: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 519: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 520: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 521: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 522: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 523: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 524: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 525: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 526: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 527: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 528: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 529: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 530: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 531: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 532: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 533: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 534: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 535: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 536: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 537: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 538: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 539: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 540: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 541: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 542: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 543: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 544: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 545: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 546: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 547: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 548: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 549: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 550: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 551: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 552: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 553: levar 2 missionários e 1 canibal da margem esquerda para a margem direita.
# Passo 554: levar 3 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 555: levar 0 missionários e 3 canibais da margem esquerda para a margem direita.
# Passo 556: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 557: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 558: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 559: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 560: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 561: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 562: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 563: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 564: levar 2 missionários e 0 canibais da margem direita para a margem esquerda.
# Passo 565: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.

# %% [markdown]
# ## DLS - Busca em Profundidade Limitada
# A busca em profundidade limitada (Depth-Limited Search) funciona como a DFS, mas com um limite máximo de profundidade. Isso evita que a busca avance indefinidamente em ramos muito longos e permite controlar o custo de exploração.

# %%
def solve_dls(initial_state, depth_limit):
    def state_to_key(state):
        return (state["left"], state["right"], state["boat"])

    initial_key = state_to_key(initial_state)
    stack = [{
        "state": initial_state,
        "path": [],
        "movements": [(0, 0)],
        "depth": 0,
        "path_keys": {initial_key}
    }]

    while stack:
        node = stack.pop()

        state = node["state"]
        path = node["path"]
        movements = node["movements"]
        depth = node["depth"]
        path_keys = node["path_keys"]

        if is_goal(state):
            return path + [state], movements

        if depth >= depth_limit:
            continue

        for move, new_state in successors(state):
            state_key = state_to_key(new_state)

            # Evita ciclos no caminho atual da busca em profundidade
            if state_key in path_keys:
                continue

            stack.append({
                "state": new_state,
                "path": path + [state],
                "movements": movements + [move],
                "depth": depth + 1,
                "path_keys": path_keys | {state_key}
            })

    return None, None

# %%
depth_limit = 0
max_depth_limit = 500
solution_dls, movements_dls = None, None

while depth_limit <= max_depth_limit:
    solution_dls, movements_dls = solve_dls(initial_state, depth_limit)

    if solution_dls is None:
        print(f"depth_limit = {depth_limit}: nenhuma solução encontrada.")
        depth_limit += 1
        continue

    print(f"depth_limit = {depth_limit}: solução encontrada!")
    break

if solution_dls is None:
    print(
        f"\nNenhuma solução encontrada até depth_limit = {max_depth_limit}."
    )
else:
    print(f"\nSolução final encontrada com depth_limit = {depth_limit}")
    print(f"Estados da solução em DLS (limite = {depth_limit}):")

    for step, (state, move) in enumerate(zip(solution_dls, movements_dls)):
        print(f"Passo {step}")
        print(state, "através de", move)
        print("-" * 30)
    print("Chegamos")

    print("\nGabarito da travessia (DLS):")
    boat_side = "left"

    for step, move in enumerate(movements_dls[1:], start=1):
        missionaries, cannibals = move
        origin = "esquerda" if boat_side == "left" else "direita"
        destination = "direita" if boat_side == "left" else "esquerda"

        missionaries_label = "missionário" if missionaries == 1 else "missionários"
        cannibals_label = "canibal" if cannibals == 1 else "canibais"

        print(
            f"Passo {step}: levar {missionaries} {missionaries_label} e "
            f"{cannibals} {cannibals_label} da margem {origin} para a margem {destination}."
        )

        boat_side = "right" if boat_side == "left" else "left"
# Out:
# depth_limit = 0: nenhuma solução encontrada.
# depth_limit = 1: nenhuma solução encontrada.
# depth_limit = 2: nenhuma solução encontrada.
# depth_limit = 3: nenhuma solução encontrada.
# depth_limit = 4: nenhuma solução encontrada.
# depth_limit = 5: nenhuma solução encontrada.
# depth_limit = 6: nenhuma solução encontrada.
# depth_limit = 7: nenhuma solução encontrada.
# depth_limit = 8: nenhuma solução encontrada.
# depth_limit = 9: solução encontrada!
#
# Solução final encontrada com depth_limit = 9
# Estados da solução em DLS (limite = 9):
# Passo 0
# {'left': (4, 4), 'right': (0, 0), 'boat': 'left'} através de (0, 0)
# ------------------------------
# Passo 1
# {'left': (3, 3), 'right': (1, 1), 'boat': 'right'} através de (1, 1)
# ------------------------------
# Passo 2
# {'left': (4, 3), 'right': (0, 1), 'boat': 'left'} através de (1, 0)
# ------------------------------
# Passo 3
# {'left': (2, 2), 'right': (2, 2), 'boat': 'right'} através de (2, 1)
# ------------------------------
# Passo 4
# {'left': (3, 3), 'right': (1, 1), 'boat': 'left'} através de (1, 1)
# ------------------------------
# Passo 5
# {'left': (0, 3), 'right': (4, 1), 'boat': 'right'} através de (3, 0)
# ------------------------------
# Passo 6
# {'left': (0, 4), 'right': (4, 0), 'boat': 'left'} através de (0, 1)
# ------------------------------
# Passo 7
# {'left': (0, 1), 'right': (4, 3), 'boat': 'right'} através de (0, 3)
# ------------------------------
# Passo 8
# {'left': (1, 1), 'right': (3, 3), 'boat': 'left'} através de (1, 0)
# ------------------------------
# Passo 9
# {'left': (0, 0), 'right': (4, 4), 'boat': 'right'} através de (1, 1)
# ------------------------------
# Chegamos
#
# Gabarito da travessia (DLS):
# Passo 1: levar 1 missionário e 1 canibal da margem esquerda para a margem direita.
# Passo 2: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 3: levar 2 missionários e 1 canibal da margem esquerda para a margem direita.
# Passo 4: levar 1 missionário e 1 canibal da margem direita para a margem esquerda.
# Passo 5: levar 3 missionários e 0 canibais da margem esquerda para a margem direita.
# Passo 6: levar 0 missionários e 1 canibal da margem direita para a margem esquerda.
# Passo 7: levar 0 missionários e 3 canibais da margem esquerda para a margem direita.
# Passo 8: levar 1 missionário e 0 canibais da margem direita para a margem esquerda.
# Passo 9: levar 1 missionário e 1 canibal da margem esquerda para a margem direita.

# %% [markdown]
# ## Parametrização TODO
# Você pode alterar o problema sem editar várias células manualmente usando a função `configure_problem` da célula abaixo.
#
# Exemplo de uso:
# - `configure_problem(total_missionaries=4, total_cannibals=4, boat_capacity=2)`
# - Depois, execute novamente as células dos algoritmos (BFS, DFS e DLS).
